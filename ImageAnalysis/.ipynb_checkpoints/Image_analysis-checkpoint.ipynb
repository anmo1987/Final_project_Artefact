# %%
Notebook for image Analysis

# %%
##Import librairies
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import os
import random
import seaborn as sns
from PIL import Image

###NEURON NETWORK LIBRAIRIES
import tensorflow as tf
from tensorflow.keras.utils import image_dataset_from_directory
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Activation, Flatten, Dense, Dropout, BatchNormalization
from keras.utils import to_categorical
from tensorflow.keras import Sequential

##ML LIBRAIRIES
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
# Out:
# 2023-08-29 14:39:23.740821: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-29 14:39:23.819912: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-29 14:39:23.821314: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-29 14:39:24.812809: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
##DATA CSV
data = pd.read_csv("./HAM10000_metadata.csv")

# %% [markdown]
# # EDA

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10015 entries, 0 to 10014
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   lesion_id     10015 non-null  object
#  1   image_id      10015 non-null  object
#  2   dx            10015 non-null  object
#  3   dx_type       10015 non-null  object
#  4   age           9958 non-null   float64
#  5   sex           10015 non-null  object
#  6   localization  10015 non-null  object
# dtypes: float64(1), object(6)
# memory usage: 547.8+ KB

# %%
data
# Out:
#          lesion_id      image_id     dx dx_type   age     sex localization
# 0      HAM_0000118  ISIC_0027419    bkl   histo  80.0    male        scalp
# 1      HAM_0000118  ISIC_0025030    bkl   histo  80.0    male        scalp
# 2      HAM_0002730  ISIC_0026769    bkl   histo  80.0    male        scalp
# 3      HAM_0002730  ISIC_0025661    bkl   histo  80.0    male        scalp
# 4      HAM_0001466  ISIC_0031633    bkl   histo  75.0    male          ear
# ...            ...           ...    ...     ...   ...     ...          ...
# 10010  HAM_0002867  ISIC_0033084  akiec   histo  40.0    male      abdomen
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male      abdomen
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male      abdomen
# 10013  HAM_0000239  ISIC_0032854  akiec   histo  80.0    male         face
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female         back
#
# [10015 rows x 7 columns]

# %%
data["dx_type"].value_counts()
# Out:
# dx_type
# histo        5340
# follow_up    3704
# consensus     902
# confocal       69
# Name: count, dtype: int64

# %%
##Preprocess & clean
data.isna().sum()
##57 missing data within Age
# Out:
# lesion_id        0
# image_id         0
# dx               0
# dx_type          0
# age             57
# sex              0
# localization     0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
##Missing data handling
##Filling with Mean by sex
data['age'] = data['age'].fillna(data.groupby(['sex'])['age'].transform('mean'))
data.isna().sum()
# Out:
# lesion_id       0
# image_id        0
# dx              0
# dx_type         0
# age             0
# sex             0
# localization    0
# dtype: int64

# %%
##Create a synthetized data frame
df = data.groupby(['sex', 'dx', 'localization']).size().unstack(fill_value=0)
mean_by_group = pd.DataFrame(data.groupby(['sex', 'dx'])['age'].mean())
age = mean_by_group["age"]
synthetized = pd.concat([df, age], axis=1)
synthetized["sum"] = synthetized["abdomen"] + synthetized["acral"] + synthetized["back"] +synthetized["chest"]+synthetized["ear"]+synthetized["face"]+ synthetized["foot"]+ synthetized["genital"]+ synthetized["hand"]+ synthetized["lower extremity"]+synthetized["neck"]+ synthetized["scalp"]+ synthetized["trunk"]+ synthetized["unknown"]+ synthetized["upper extremity"]

# %%
synthetized
# Out:
#                abdomen  acral  back  chest  ear  face  foot  genital  hand  \
# sex     dx
# female  akiec        1      0     5      3    0    48     0        0     4
#         bcc          9      0    69     12    0    44     3        0     2
#         bkl         19      0    55     35    2   162     1        2     9
#         df           0      0     0      0    0     0     0        1     0
#         mel         15      0   100     12    6    38    15        0     1
#         nv         372      7   604     76   22    51   154       31    36
#         vasc        17      0    10      4    0     5     0        0     5
# male    akiec        4      0    24      9    3    65     0        0     9
#         bcc          9      0   117     35    0    57     1        0     0
#         bkl         23      0   147     39    4   157     0        0     5
#         df           4      0     2      0    0     0     2        0     0
#         mel         51      0   224     56   11    66    13        0     0
#         nv         486      0   821    124    8    49   127       14    19
#         vasc        10      0    12      2    0     3     0        0     0
# unknown bkl          0      0     0      0    0     0     0        0     0
#         nv           2      0     2      0    0     0     3        0     0
#
#                lower extremity  neck  scalp  trunk  unknown  upper extremity  \
# sex     dx
# female  akiec               23     3      0      0        0               19
#         bcc                 21     7      7      2        2               19
#         bkl                100    15      3     32        2               26
#         df                  43     0      0      0        0                8
#         mel                122    12      2      9        1               91
#         nv                 827    33     19    585       90              330
#         vasc                16     3      0     10        0                3
# male    akiec               42     7     14      1        0               43
#         bcc                 37     7     12      9        3               30
#         bkl                 74    16     31     41       11               78
#         df                  39     0      0      0        0               16
#         mel                 70    17     12     38        9              122
#         nv                 652    48     26    653       69              325
#         vasc                11     0      2     21        0                8
# unknown bkl                  0     0      0      0       10                0
#         nv                   0     0      0      3       37                0
#
#                      age   sum
# sex     dx
# female  akiec  66.698113   106
#         bcc    65.228426   197
#         bkl    62.494600   463
#         df     49.326923    52
#         mel    56.391509   424
#         nv     44.110240  3237
#         vasc   49.589041    73
# male    akiec  66.447964   221
#         bcc    67.823344   317
#         bkl    65.607029   626
#         df     56.111111    63
#         mel    63.300567   689
#         nv     48.755680  3421
#         vasc   53.260870    69
# unknown bkl    37.500000    10
#         nv     37.500000    47

# %%
###Being very few the unknown dataset is removed
condition = data['sex'] != "unknown"
data_filt = data[condition]
data_filt = data_filt.reset_index(drop=True)
data_filt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9958 entries, 0 to 9957
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   lesion_id     9958 non-null   object
#  1   image_id      9958 non-null   object
#  2   dx            9958 non-null   object
#  3   dx_type       9958 non-null   object
#  4   age           9958 non-null   float64
#  5   sex           9958 non-null   object
#  6   localization  9958 non-null   object
# dtypes: float64(1), object(6)
# memory usage: 544.7+ KB

# %% [markdown]
# # Graphical representation data

# %%
##Box plot Skin disease by age and sex
ax = sns.boxplot(data= data_filt, y = "dx", x="age", hue="sex")
ax.set_yticklabels(["benign keratosis-like lesions", "melanocytic nevi", "dermatofibroma", "melanoma ","vascular lesions","basal cell carcinoma", "Actinic keratoses"  ])
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
plt.title("Box Plot Skin disease by age and sex")
plt.show()

# %%
##CAMEMBERT PLOT
data_women = data_filt[data_filt["sex"]=="female"]
piedata_w = pd.DataFrame(data_women["dx"].value_counts())
data_women = data_filt[data_filt["sex"]=="male"]
piedata_m = pd.DataFrame(data_women["dx"].value_counts())
labels = ["melanocytic nevi","benign keratosis-like lesions","melanoma ", "basal cell carcinoma", "Actinic keratoses", "vascular lesions", "dermatofibroma"]

fig, ax = plt.subplots(1,2, figsize=(10,5))
ax[0].pie(piedata_w["count"], labels=labels, autopct='%.1f%%')
ax[0].set_title('Woman skin diseases repartition')
ax[1].pie(piedata_m["count"], labels=labels, autopct='%.1f%%')
ax[1].set_title('Man skin diseases repartition')
plt.tight_layout()

# %%
###Bar plot
plt.figure(figsize=(25,10))
ax = sns.countplot(y='localization', hue='dx',data=data_filt)
plt.legend(
    labels = ["benign keratosis-like lesions", "melanocytic nevi", "dermatofibroma", "melanoma ","vascular lesions","basal cell carcinoma", "Actinic keratoses"  ],
    fontsize='large',
    title='Skin diseases',
    title_fontsize='x-large')
plt.title('Disease localization',fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Disease localization')

# %%
###Bar plot skin diseases diagnoses
data_filt['dx_type'].value_counts().plot.pie(autopct="%1.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
###Prepare dataset for pca
pca_data = data_filt
var_to_keep = ["dx", "dx_type", "age", "sex", "localization"]
pca_data = pca_data[var_to_keep]
pca_data
# Out:
#          dx dx_type   age     sex localization
# 0       bkl   histo  80.0    male        scalp
# 1       bkl   histo  80.0    male        scalp
# 2       bkl   histo  80.0    male        scalp
# 3       bkl   histo  80.0    male        scalp
# 4       bkl   histo  75.0    male          ear
# ...     ...     ...   ...     ...          ...
# 9953  akiec   histo  40.0    male      abdomen
# 9954  akiec   histo  40.0    male      abdomen
# 9955  akiec   histo  40.0    male      abdomen
# 9956  akiec   histo  80.0    male         face
# 9957    mel   histo  70.0  female         back
#
# [9958 rows x 5 columns]

# %%
pca_data["localization"].value_counts()
# Out:
# localization
# back               2190
# lower extremity    2077
# trunk              1401
# upper extremity    1118
# abdomen            1020
# face                745
# chest               407
# foot                316
# unknown             187
# neck                168
# scalp               128
# hand                 90
# ear                  56
# genital              48
# acral                 7
# Name: count, dtype: int64

# %%
##Replace qualiative variable to quanti
lesion_type_dict = {
    'nv': '1',
    'mel': '2',
    'bkl': '3',
    'bcc': '4',
    'akiec': '5',
    'vasc': '6',
    'df': '7'
}
pca_data['disease'] = pca_data['dx'].map(lesion_type_dict.get) 
pca_data["sex"] = pca_data["sex"].map({'female':0, 'male':1})
pca_data["dx_type"] = pca_data["dx_type"].map({'histo':0, 'follow_up':1, 'consensus':2, 'confocal':3})
pca_data["localization"] = pca_data["localization"].map({'back':0, 'lower extremity':1, 'trunk':2, 'upper extremity':3,
                                                        'abdomen':4,'face':5,'chest':6,
                                                        'foot':7,'unknown':8,'neck':9,'scalp':10,'hand':11,'ear':12,'genital':13,'acral':14})
pca_data_1 = pca_data.drop("dx", axis=1)
# Out:
# /tmp/ipykernel_308811/794679723.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pca_data['disease'] = pca_data['dx'].map(lesion_type_dict.get)
# /tmp/ipykernel_308811/794679723.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pca_data["sex"] = pca_data["sex"].map({'female':0, 'male':1})
# /tmp/ipykernel_308811/794679723.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pca_data["dx_type"] = pca_data["dx_type"].map({'histo':0, 'follow_up':1, 'consensus':2, 'confocal':3})
# /tmp/ipykernel_308811/794679723.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pca_data["localization"] = pca_data["localization"].map({'back':0, 'lower extremity':1, 'trunk':2, 'upper extremity':3,
#          dx  dx_type   age  sex  localization disease
# 0       bkl        0  80.0    1            10       3
# 1       bkl        0  80.0    1            10       3
# 2       bkl        0  80.0    1            10       3
# 3       bkl        0  80.0    1            10       3
# 4       bkl        0  75.0    1            12       3
# ...     ...      ...   ...  ...           ...     ...
# 9953  akiec        0  40.0    1             4       5
# 9954  akiec        0  40.0    1             4       5
# 9955  akiec        0  40.0    1             4       5
# 9956  akiec        0  80.0    1             5       5
# 9957    mel        0  70.0    0             0       2
#
# [9958 rows x 6 columns]

# %%
##Compute PCA
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

pipeline = Pipeline([("scaler", StandardScaler()), ("pca", PCA(n_components=4)),])
pca_data = pca_data.drop("dx", axis=1)
pca_data = pd.DataFrame(pipeline.fit_transform(pca_data.drop("dx", axis=1)), columns=["PC1", "PC2", "PC3", "PC4"])
#pca_data["species"] = iris_df["species"]

pca_step = pipeline.steps[1][1]
loadings = pd.DataFrame(
    pca_step.components_.T,
    columns=["PC1", "PC2"],
    index=data.columns,
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[135], line 7
#       4 from sklearn.preprocessing import StandardScaler
#       6 pipeline = Pipeline([("scaler", StandardScaler()), ("pca", PCA(n_components=4)),])
# ----> 7 pca_data = pca_data.drop("dx", axis=1)
#       8 pca_data = pd.DataFrame(pipeline.fit_transform(pca_data), columns=["PC1", "PC2", "PC3", "PC4"])
#       9 #pca_data["species"] = iris_df["species"]
#
# File ~/.pyenv/versions/3.10.4/envs/artefact/lib/python3.10/site-packages/pandas/core/frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# File ~/.pyenv/versions/3.10.4/envs/artefact/lib/python3.10/site-packages/pandas/core/generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File ~/.pyenv/versions/3.10.4/envs/artefact/lib/python3.10/site-packages/pandas/core/generic.py:4591, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4589         new_axis = axis.drop(labels, level=level, errors=errors)
#    4590     else:
# -> 4591         new_axis = axis.drop(labels, errors=errors)
#    4592     indexer = axis.get_indexer(new_axis)
#    4594 # Case for non-unique axis
#    4595 else:
#
# File ~/.pyenv/versions/3.10.4/envs/artefact/lib/python3.10/site-packages/pandas/core/indexes/base.py:6696, in Index.drop(self, labels, errors)
#    6694 if mask.any():
#    6695     if errors != "ignore":
# -> 6696         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6697     indexer = indexer[~mask]
#    6698 return self.delete(indexer)
#
# KeyError: "['dx'] not found in axis"

# %%
pca_data
# Out:
#            PC1       PC2       PC3       PC4
# 0     2.459369  1.901565  0.999004 -1.053904
# 1     2.459369  1.901565  0.999004 -1.053904
# 2     2.459369  1.901565  0.999004 -1.053904
# 3     2.459369  1.901565  0.999004 -1.053904
# 4     2.344937  2.541819  1.206665 -1.426921
# ...        ...       ...       ...       ...
# 9953  1.680498  0.460484 -0.068303 -0.433716
# 9954  1.680498  0.460484 -0.068303 -0.433716
# 9955  1.680498  0.460484 -0.068303 -0.433716
# 9956  3.190629  0.673062  0.226829  0.189299
# 9957  0.653686 -0.496912 -1.542946  0.631430
#
# [9958 rows x 4 columns]
